# %% [markdown]
# # Finding season-dependent keywords
#
# In this notebook, we investigate the reviews based on the season in which they were written. We will find words that are more commonly used in the winter season (specifically from January until March) and those that are more commonly used during the summer (specifically from July until September).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
from nltk.tokenize import RegexpTokenizer
import statsmodels.formula.api as smf

# %%
DATA_PATH = './datasets/BeerAdvocate/'

# %%
# load Beer Advocate data from pickles
reviews = pd.read_pickle(DATA_PATH + 'reviews.pkl')
reviews.head()
# Out:
#        Beer Name  Beer Id                               Brewery Name  \
# 0          Régab   142544  Societe des Brasseries du Gabon (SOBRAGA)
# 1  Barelegs Brew    19590       Strangford Lough Brewing Company Ltd
# 2  Barelegs Brew    19590       Strangford Lough Brewing Company Ltd
# 3  Barelegs Brew    19590       Strangford Lough Brewing Company Ltd
# 4  Barelegs Brew    19590       Strangford Lough Brewing Company Ltd
#
#    Brewery Id             Style  Abv                Date         Username  \
# 0       37262   Euro Pale Lager  4.5 2015-08-20 12:00:00          nmann08
# 1       10093  English Pale Ale  4.5 2009-02-20 12:00:00      StJamesGate
# 2       10093  English Pale Ale  4.5 2006-03-13 12:00:00          mdagnew
# 3       10093  English Pale Ale  4.5 2004-12-01 12:00:00  helloloser12345
# 4       10093  English Pale Ale  4.5 2004-08-30 12:00:00       cypressbob
#
#                  User Id  Appearance  Aroma  Palate  Taste  Overall  Rating  \
# 0         nmann08.184925        3.25   2.75    3.25   2.75      3.0    2.88
# 1     stjamesgate.163714        3.00   3.50    3.50   4.00      3.5    3.67
# 2          mdagnew.19527        4.00   3.50    3.50   4.00      3.5    3.73
# 3  helloloser12345.10867        4.00   3.50    4.00   4.00      4.5    3.98
# 4        cypressbob.3708        4.00   4.00    4.00   4.00      4.0    4.00
#
#                                                 Text Review
# 0  From a bottle, pours a piss yellow color with ...   None
# 1  Pours pale copper with a thin head that quickl...   None
# 2  500ml Bottle bought from The Vintage, Antrim.....   None
# 3  Serving: 500ml brown bottlePour: Good head wit...   None
# 4  500ml bottlePours with a light, slightly hazy ...   None

# %%
#Find the Month in which the review has been written
reviews['Month'] = reviews['Date'].apply(lambda x: x.month) #adding Month data
styles = reviews['Style'].unique()

# %%
def get_words(text):
    word_tokenizer = RegexpTokenizer(r'[a-zA-Z]+')
    word_list = word_tokenizer.tokenize(text)
    lowercase_words = list(map(lambda x: x.lower(),word_list))
    return lowercase_words

# %%
def get_indicator(words,keyword):
    if keyword in words:
        return 1
    else:
        return 0

# %%
thresh = 0.1

styles = ['American IPA', 'American Double / Imperial IPA',
       'American Double / Imperial Stout', 'American Pale Ale (APA)',
       'Russian Imperial Stout', 'Saison / Farmhouse Ale', 'American Porter',
       'American Amber / Red Ale', 'American Wild Ale',
       'Fruit / Vegetable Beer', 'Belgian Strong Dark Ale',
       'American Strong Ale', 'Witbier', 'American Brown Ale', 'Tripel',
       'Belgian Strong Pale Ale', 'American Stout', 'American Barleywine',
       'Hefeweizen', 'American Adjunct Lager', 'American Pale Wheat Ale']

for style in styles:
    
    winter_reviews = reviews[(1<=reviews.Month)&(reviews.Month<=3)&(reviews.Style==style)]
    summer_reviews = reviews[(7<=reviews.Month)&(reviews.Month<=9)&(reviews.Style==style)]
    
    winter_words = (winter_reviews)['Text'].apply(get_words).explode()
    summer_words = (summer_reviews)['Text'].apply(get_words).explode()
    n = 100
    winter_total = len(winter_words)
    summer_total = len(summer_words)
    winter_counts = winter_words.value_counts()[:n]
    summer_counts = summer_words.value_counts()[:n]
    winter_large = winter_words.value_counts()
    summer_large = summer_words.value_counts()
    print('Style: {}'.format(style))
    keywords = []
    for word in winter_counts.keys():
        winter_freq = winter_counts[word]/winter_total
        summer_freq = summer_large[word]/summer_total
        if (winter_freq-summer_freq)/winter_freq > thresh:
            keywords.append(word)
            print("\t {} appears {:.5f}% in winter and {:.5f}% in summer".format(word,100*winter_freq,100*summer_freq));
    for word in summer_counts.keys():
        summer_freq = summer_counts[word]/summer_total
        winter_freq = winter_large[word]/winter_total
        if (summer_freq-winter_freq)/summer_freq > thresh:
            keywords.append(word)
            print("\t {} appears {:.5f}% in summer and {:.5f}% in winter".format(word,100*summer_freq,100*winter_freq));
    
    if len(keywords)==0:
        continue
    
    all_rev = pd.concat([winter_reviews,summer_reviews])
    all_rev['Words'] = all_rev['Text'].apply(get_words)

    
    formula = "Rating ~ "
    
    cnt = 0
    
    for keyword in keywords:
        if cnt == 0:
            formula = formula + keyword
        else:
            formula = formula + " + " + keyword
            
        all_rev[keyword] = all_rev['Words'].apply((lambda words: get_indicator(words,keyword)))
        cnt += 1
    
    model = smf.ols(formula=formula, data=all_rev).fit()

    model_summary = model.summary()

    print(model_summary)
# Out:
# Style: American IPA
# 	 caramel appears 0.25976% in summer and 0.22846% in winter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     379.7
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):           1.98e-84
# Time:                        02:20:36   Log-Likelihood:                -89483.
# No. Observations:              124693   AIC:                         1.790e+05
# Df Residuals:                  124691   BIC:                         1.790e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.9449      0.002   2516.520      0.000       3.942       3.948
# caramel       -0.0688      0.004    -19.485      0.000      -0.076      -0.062
# ==============================================================================
# Omnibus:                    21204.877   Durbin-Watson:                   1.341
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            49437.026
# Skew:                          -0.976   Prob(JB):                         0.00
# Kurtosis:                       5.388   Cond. No.                         2.63
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: American Double / Imperial IPA
# 	 caramel appears 0.27959% in summer and 0.23134% in winter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1000.
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):          2.09e-218
# Time:                        02:20:46   Log-Likelihood:                -68371.
# No. Observations:               95034   AIC:                         1.367e+05
# Df Residuals:                   95032   BIC:                         1.368e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.1344      0.002   2256.993      0.000       4.131       4.138
# caramel       -0.1219      0.004    -31.628      0.000      -0.129      -0.114
# ==============================================================================
# Omnibus:                    21482.368   Durbin-Watson:                   1.363
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            61627.584
# Skew:                          -1.190   Prob(JB):                         0.00
# Kurtosis:                       6.146   Cond. No.                         2.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: American Double / Imperial Stout
# 	 bourbon appears 0.44202% in winter and 0.38913% in summer
# 	 barrel appears 0.20052% in winter and 0.17857% in summer
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     604.3
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):          1.59e-260
# Time:                        02:20:52   Log-Likelihood:                -42100.
# No. Observations:               58998   AIC:                         8.421e+04
# Df Residuals:                   58995   BIC:                         8.423e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.1425      0.002   1706.961      0.000       4.138       4.147
# bourbon        0.1605      0.005     32.936      0.000       0.151       0.170
# barrel         0.0024      0.006      0.410      0.681      -0.009       0.014
# ==============================================================================
# Omnibus:                    16855.114   Durbin-Watson:                   1.400
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            62242.449
# Skew:                          -1.404   Prob(JB):                         0.00
# Kurtosis:                       7.176   Cond. No.                         3.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: American Pale Ale (APA)
# Style: Russian Imperial Stout
# 	 hops appears 0.18693% in winter and 0.16049% in summer
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     46.49
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):           9.35e-12
# Time:                        02:21:00   Log-Likelihood:                -29194.
# No. Observations:               40743   AIC:                         5.839e+04
# Df Residuals:                   40741   BIC:                         5.841e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.1061      0.003   1516.020      0.000       4.101       4.111
# hops           0.0437      0.006      6.818      0.000       0.031       0.056
# ==============================================================================
# Omnibus:                    10909.058   Durbin-Watson:                   1.443
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36032.526
# Skew:                          -1.352   Prob(JB):                         0.00
# Kurtosis:                       6.730   Cond. No.                         2.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: Saison / Farmhouse Ale
# 	 would appears 0.18471% in winter and 0.16422% in summer
# 	 spice appears 0.23666% in summer and 0.20753% in winter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     15.07
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):           2.87e-07
# Time:                        02:21:05   Log-Likelihood:                -25968.
# No. Observations:               38772   AIC:                         5.194e+04
# Df Residuals:                   38769   BIC:                         5.197e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.9501      0.003   1351.729      0.000       3.944       3.956
# would         -0.0320      0.006     -5.103      0.000      -0.044      -0.020
# spice         -0.0118      0.006     -2.000      0.045      -0.023      -0.000
# ==============================================================================
# Omnibus:                     8822.220   Durbin-Watson:                   1.449
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            27441.554
# Skew:                          -1.167   Prob(JB):                         0.00
# Kurtosis:                       6.396   Cond. No.                         2.79
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: American Porter
# Style: American Amber / Red Ale
# 	 citrus appears 0.31312% in winter and 0.27332% in summer
# 	 pine appears 0.20927% in winter and 0.17194% in summer
# 	 clear appears 0.19349% in winter and 0.17297% in summer
# 	 ale appears 0.38552% in summer and 0.33886% in winter
# 	 dark appears 0.23992% in summer and 0.20750% in winter
# 	 brown appears 0.22544% in summer and 0.19381% in winter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     331.9
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):               0.00
# Time:                        02:21:12   Log-Likelihood:                -27279.
# No. Observations:               35314   AIC:                         5.457e+04
# Df Residuals:                   35307   BIC:                         5.463e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.6558      0.004    824.935      0.000       3.647       3.664
# citrus         0.1677      0.007     24.762      0.000       0.154       0.181
# pine           0.2182      0.008     27.223      0.000       0.202       0.234
# clear         -0.0318      0.007     -4.615      0.000      -0.045      -0.018
# ale            0.0227      0.006      3.715      0.000       0.011       0.035
# dark           0.0524      0.007      7.705      0.000       0.039       0.066
# brown         -0.0084      0.007     -1.195      0.232      -0.022       0.005
# ==============================================================================
# Omnibus:                     3986.430   Durbin-Watson:                   1.406
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7035.325
# Skew:                          -0.769   Prob(JB):                         0.00
# Kurtosis:                       4.553   Cond. No.                         3.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: American Wild Ale
# Style: Fruit / Vegetable Beer
# 	 cherry appears 0.28667% in winter and 0.24324% in summer
# 	 apple appears 0.16647% in winter and 0.11450% in summer
# 	 d appears 0.16518% in winter and 0.14399% in summer
# 	 wheat appears 0.27863% in summer and 0.22887% in winter
# 	 beers appears 0.18110% in summer and 0.16252% in winter
# 	 blueberry appears 0.16263% in summer and 0.12594% in winter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     87.53
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):          3.99e-109
# Time:                        02:21:17   Log-Likelihood:                -28513.
# No. Observations:               26281   AIC:                         5.704e+04
# Df Residuals:                   26274   BIC:                         5.710e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.4527      0.006    556.848      0.000       3.441       3.465
# cherry         0.2143      0.013     16.942      0.000       0.189       0.239
# apple          0.0938      0.017      5.646      0.000       0.061       0.126
# d             -0.0279      0.012     -2.353      0.019      -0.051      -0.005
# wheat         -0.0884      0.011     -7.782      0.000      -0.111      -0.066
# beers          0.0982      0.012      8.421      0.000       0.075       0.121
# blueberry     -0.1017      0.016     -6.287      0.000      -0.133      -0.070
# ==============================================================================
# Omnibus:                     2747.778   Durbin-Watson:                   1.269
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3836.177
# Skew:                          -0.832   Prob(JB):                         0.00
# Kurtosis:                       3.858   Cond. No.                         4.15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: Belgian Strong Dark Ale
# Style: American Strong Ale
# 	 chocolate appears 0.24595% in winter and 0.19939% in summer
# 	 vanilla appears 0.23438% in winter and 0.20542% in summer
# 	 smooth appears 0.20328% in winter and 0.18163% in summer
# 	 malt appears 0.46171% in summer and 0.41352% in winter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.041
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     217.5
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):          3.83e-183
# Time:                        02:21:21   Log-Likelihood:                -16406.
# No. Observations:               20419   AIC:                         3.282e+04
# Df Residuals:                   20414   BIC:                         3.286e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.8844      0.006    668.454      0.000       3.873       3.896
# chocolate      0.0562      0.010      5.693      0.000       0.037       0.076
# vanilla        0.1552      0.010     15.950      0.000       0.136       0.174
# smooth         0.1902      0.009     21.095      0.000       0.173       0.208
# malt           0.0301      0.008      3.874      0.000       0.015       0.045
# ==============================================================================
# Omnibus:                     5908.382   Durbin-Watson:                   1.412
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            20818.231
# Skew:                          -1.438   Prob(JB):                         0.00
# Kurtosis:                       7.024   Cond. No.                         3.29
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: Witbier
# 	 smell appears 0.32529% in winter and 0.29046% in summer
# 	 be appears 0.29625% in winter and 0.26326% in summer
# 	 would appears 0.23668% in winter and 0.19506% in summer
# 	 wit appears 0.29283% in summer and 0.22327% in winter
# 	 refreshing appears 0.24636% in summer and 0.20903% in winter
# 	 notes appears 0.23751% in summer and 0.21319% in winter
# 	 pale appears 0.20103% in summer and 0.17444% in winter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     79.19
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):          5.05e-114
# Time:                        02:21:32   Log-Likelihood:                -17571.
# No. Observations:               21630   AIC:                         3.516e+04
# Df Residuals:                   21622   BIC:                         3.522e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.6337      0.006    593.460      0.000       3.622       3.646
# smell         -0.0167      0.008     -2.025      0.043      -0.033      -0.001
# be            -0.0362      0.009     -4.021      0.000      -0.054      -0.019
# would         -0.0545      0.010     -5.647      0.000      -0.073      -0.036
# wit            0.0590      0.009      6.511      0.000       0.041       0.077
# refreshing     0.1747      0.009     19.729      0.000       0.157       0.192
# notes          0.0650      0.009      6.889      0.000       0.047       0.084
# pale          -0.0122      0.009     -1.294      0.196      -0.031       0.006
# ==============================================================================
# Omnibus:                     2825.547   Durbin-Watson:                   1.511
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5169.260
# Skew:                          -0.854   Prob(JB):                         0.00
# Kurtosis:                       4.679   Cond. No.                         3.38
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: American Brown Ale
# 	 roasted appears 0.33610% in summer and 0.29835% in winter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     84.53
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):           4.16e-20
# Time:                        02:21:34   Log-Likelihood:                -14053.
# No. Observations:               19854   AIC:                         2.811e+04
# Df Residuals:                   19852   BIC:                         2.812e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.8209      0.004    941.295      0.000       3.813       3.829
# roasted        0.0728      0.008      9.194      0.000       0.057       0.088
# ==============================================================================
# Omnibus:                     3454.670   Durbin-Watson:                   1.504
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8196.065
# Skew:                          -0.988   Prob(JB):                         0.00
# Kurtosis:                       5.450   Cond. No.                         2.46
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: Tripel
# Style: Belgian Strong Pale Ale
# 	 spicy appears 0.22288% in summer and 0.19976% in winter
# 	 spice appears 0.21787% in summer and 0.18851% in winter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     45.33
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):           2.26e-20
# Time:                        02:21:38   Log-Likelihood:                -15347.
# No. Observations:               21245   AIC:                         3.070e+04
# Df Residuals:                   21242   BIC:                         3.072e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.9002      0.004    934.844      0.000       3.892       3.908
# spicy          0.0659      0.008      7.771      0.000       0.049       0.083
# spice          0.0444      0.009      5.199      0.000       0.028       0.061
# ==============================================================================
# Omnibus:                     3657.911   Durbin-Watson:                   1.515
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7984.855
# Skew:                          -1.010   Prob(JB):                         0.00
# Kurtosis:                       5.223   Cond. No.                         2.68
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: American Stout
# Style: American Barleywine
# 	 dark appears 0.48143% in summer and 0.42352% in winter
# 	 brown appears 0.39801% in summer and 0.33910% in winter
# 	 toffee appears 0.24934% in summer and 0.21086% in winter
# 	 sugar appears 0.21061% in summer and 0.17260% in winter
# 	 quite appears 0.18721% in summer and 0.16775% in winter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     24.05
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):           3.30e-24
# Time:                        02:21:42   Log-Likelihood:                -13468.
# No. Observations:               19993   AIC:                         2.695e+04
# Df Residuals:                   19987   BIC:                         2.700e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.9666      0.005    745.653      0.000       3.956       3.977
# dark           0.0554      0.007      7.998      0.000       0.042       0.069
# brown          0.0103      0.008      1.353      0.176      -0.005       0.025
# toffee         0.0488      0.008      5.942      0.000       0.033       0.065
# sugar         -0.0007      0.009     -0.072      0.943      -0.019       0.018
# quite          0.0079      0.009      0.913      0.361      -0.009       0.025
# ==============================================================================
# Omnibus:                     4460.848   Durbin-Watson:                   1.582
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12446.981
# Skew:                          -1.183   Prob(JB):                         0.00
# Kurtosis:                       6.057   Cond. No.                         3.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: Hefeweizen
# 	 be appears 0.29171% in winter and 0.25560% in summer
# 	 would appears 0.20975% in winter and 0.18741% in summer
# 	 quot appears 0.19499% in winter and 0.17340% in summer
# 	 clove appears 0.56710% in summer and 0.47977% in winter
# 	 hefe appears 0.46782% in summer and 0.41883% in winter
# 	 refreshing appears 0.21079% in summer and 0.18638% in winter
# 	 nose appears 0.20771% in summer and 0.18672% in winter
# 	 spice appears 0.19428% in summer and 0.17241% in winter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     73.70
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):          2.47e-120
# Time:                        02:21:44   Log-Likelihood:                -17345.
# No. Observations:               20397   AIC:                         3.471e+04
# Df Residuals:                   20388   BIC:                         3.478e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.6815      0.007    539.744      0.000       3.668       3.695
# be            -0.0130      0.010     -1.330      0.184      -0.032       0.006
# would         -0.0477      0.011     -4.481      0.000      -0.069      -0.027
# quot          -0.0366      0.014     -2.571      0.010      -0.065      -0.009
# clove          0.1223      0.008     15.003      0.000       0.106       0.138
# hefe           0.0388      0.008      4.561      0.000       0.022       0.055
# refreshing     0.1479      0.010     14.956      0.000       0.129       0.167
# nose           0.0035      0.010      0.343      0.731      -0.016       0.023
# spice          0.0638      0.011      5.931      0.000       0.043       0.085
# ==============================================================================
# Omnibus:                     1384.222   Durbin-Watson:                   1.279
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1866.731
# Skew:                          -0.605   Prob(JB):                         0.00
# Kurtosis:                       3.856   Cond. No.                         4.52
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Style: American Adjunct Lager
# Style: American Pale Wheat Ale
# 	 be appears 0.32201% in winter and 0.27772% in summer
# 	 would appears 0.26454% in winter and 0.21460% in summer
# 	 fruit appears 0.18704% in winter and 0.15762% in summer
# 	 summer appears 0.32045% in summer and 0.15715% in winter
# 	 refreshing appears 0.23396% in summer and 0.18504% in winter
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Rating   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     80.50
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):           9.73e-84
# Time:                        02:21:48   Log-Likelihood:                -14593.
# No. Observations:               16201   AIC:                         2.920e+04
# Df Residuals:                   16195   BIC:                         2.925e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.5275      0.007    531.860      0.000       3.514       3.540
# be            -0.0628      0.011     -5.565      0.000      -0.085      -0.041
# would         -0.0144      0.012     -1.200      0.230      -0.038       0.009
# fruit          0.1128      0.014      8.037      0.000       0.085       0.140
# summer         0.1147      0.011     10.113      0.000       0.092       0.137
# refreshing     0.1471      0.012     12.598      0.000       0.124       0.170
# ==============================================================================
# Omnibus:                      824.827   Durbin-Watson:                   1.236
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1028.398
# Skew:                          -0.523   Prob(JB):                    4.85e-224
# Kurtosis:                       3.656   Cond. No.                         3.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
